# %%
#checking the gcloud storage connection 

#import libraries 

from google.cloud import storage 
import os 
import pandas as pd 
from io import StringIO

# %%
#importing the service account key which is downloaded when key is created JSON

storage_client = storage.Client.from_service_account_json("key.json")
bucket_name = "test-28-07"
bucket = storage_client.get_bucket(bucket_name)
bucket
# Out:
# <Bucket: test-28-07>

# %%
#accesing the files in the cloud storage 
blob = bucket.get_blob("customer.csv")
if blob is None:
    print("none")
else:
    print("file found")
# Out:
# file found

# %%
#reading the csv file 
downloaded_blob = blob.download_as_string()
s=str(downloaded_blob, 'utf-8')
data= StringIO(s)
df=pd.read_csv(data)
df.head()
# Out:
#    CustomerID FirstName LastName                      Email PhoneNumber  \
# 0           1      John      Doe       john.doe@example.com    555-1234
# 1           2      Jane    Smith     jane.smith@example.com    555-5678
# 2           3     Emily    Jones    emily.jones@example.com    555-8765
# 3           4   Michael    Brown  michael.brown@example.com    555-4321
# 4           5     Alice  Johnson  alice.johnson@example.com    555-6789
#
#         Address         City State  ZipCode Country
# 0    123 Elm St  Springfield    IL    62701     USA
# 1    456 Oak St    Rivertown    CA    90210     USA
# 2   789 Pine St     Laketown    FL    32004     USA
# 3  101 Maple St      Hilltop    TX    73301     USA
# 4  202 Cedar St   Brookfield    NY    11211     USA

# %%
#now connecting to mysql database created 
import sqlite3
#from google.cloud import storage 
import pandas as pd
import numpy as np
from datetime import datetime
import mysql.connector
import sys

# %%
#make sure connection is working without any errors 
connection= mysql.connector.connect(user='admin', password='admin', host='34.173.114.106', 
                              database='test')

# %%
# checking the sample table created for testing 
cursor = cnx.cursor()
query1 = ("select * from sample")
cursor.execute(query1)


#### Create dataframe from resultant table ####
frame = pd.DataFrame(cursor.fetchall())

frame.head()
# Out:
#      0  1
# 0  ram  1

# %%
#we got the file and stored in pandas data frame now we need to insert the data into table make sure schema is created else create according to the data 
# Define the table name
# Define the insertion query
insert_query = """
INSERT INTO Customers (CustomerID, FirstName, LastName, Email, PhoneNumber, Address, City, State, ZipCode, Country)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Insert data into the table row by row
for i, row in df.iterrows():
    cursor.execute(insert_query, tuple(row))



# Commit the transaction
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[97], line 11
#       9 # Insert data into the table row by row
#      10 for i, row in df.iterrows():
# ---> 11     cursor.execute(insert_query, tuple(row))
#      15 # Commit the transaction
#      16 connection.commit()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\cursor.py:551, in MySQLCursor.execute(self, operation, params, multi)
#     549 else:
#     550     try:
# --> 551         self._handle_result(self._connection.cmd_query(stmt))
#     552     except errors.InterfaceError:
#     553         if self._connection._have_next_result:  # pylint: disable=W0212
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\connection.py:490, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     488 if not isinstance(query, bytes):
# ...

# %%
# checking the Customer table created for testing 
cursor = cnx.cursor()
query1 = ("select * from Customers")
cursor.execute(query1)


#### Create dataframe from resultant table ####
frame = pd.DataFrame(cursor.fetchall())

frame.head()
# Out:
#    0        1        2                          3         4             5  \
# 0  1     John      Doe       john.doe@example.com  555-1234    123 Elm St
# 1  2     Jane    Smith     jane.smith@example.com  555-5678    456 Oak St
# 2  3    Emily    Jones    emily.jones@example.com  555-8765   789 Pine St
# 3  4  Michael    Brown  michael.brown@example.com  555-4321  101 Maple St
# 4  5    Alice  Johnson  alice.johnson@example.com  555-6789  202 Cedar St
#
#              6   7      8    9
# 0  Springfield  IL  62701  USA
# 1    Rivertown  CA  90210  USA
# 2     Laketown  FL  32004  USA
# 3      Hilltop  TX  73301  USA
# 4   Brookfield  NY  11211  USA
